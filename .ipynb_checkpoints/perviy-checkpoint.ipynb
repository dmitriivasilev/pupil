# %%
# %matplotlib inline
from tqdm import tqdm,trange
import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import time 
from matplotlib import pyplot as plt
print("OpenCV Version : %s " % cv2.__version__)
# Out:
# OpenCV Version : 3.4.0

# %%
frames = []

cap = cv2.VideoCapture('data.mj2')

for i in trange(1000):
            
    ret, frame = cap.read()

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    frames.append(gray)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:02<00:00, 417.68it/s]

# %%
len(frames)
frames[0].shape

plt.imshow(frames[0])

# %%
def find_pupple(raw_image,last_result):
    blurred_image = cv2.GaussianBlur(raw_image,(29,29),0)
  
    thresh = cv2.adaptiveThreshold(blurred_image,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,141,35)
    
    image, contours, hierarchy = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
    
    contour_image = cv2.drawContours(raw_image.copy(), contours, -1, (255,255,255), 3)

    filtered_contours = [cnt for cnt in contours if (len(cnt)<1000) and (len(cnt)>200)]

    ellipses = [] 
    for cnt in filtered_contours: 
        try: 
            ellipses.append(cv2.fitEllipse(cnt)) 
        except: 
            pass 

    loss = [] 

    for ellipse,contour in zip(ellipses,filtered_contours): 
        
        loss.append(abs((np.pi/4 * ellipse[1][0] * ellipse[1][1])-(cv2.contourArea(contour))))
        
    loss = np.asarray(loss)

    try:
        return cv2.ellipse(raw_image,ellipses[np.argmin(loss)],(255,255,255),2)
    except:
        return last_result

# %%
otrabotanniy = frames[0]
last_result = frames[0]
for i in trange(1000):
    otrabotanniy.append(find_pupple(frames[i],otrabotanniy[-1]))
# Out:
#   4%|███▏                                                                            | 40/1000 [00:00<00:22, 41.91it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-9c1bb4909d72> in find_pupple(raw_image)
#      27     try:
# ---> 28         cv2.ellipse(raw_image,ellipses[np.argmin(loss)],(255,255,255),2)
#      29         last_result = cv2.ellipse(raw_image,ellipses[np.argmin(loss)],(255,255,255),2)
#
# ~\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py in argmin(a, axis, out)
#    1018     """
# -> 1019     return _wrapfunc(a, 'argmin', axis=axis, out=out)
#    1020
#
# ~\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      56     try:
# ---> 57         return getattr(obj, method)(*args, **kwds)
#      58
#
# ValueError: attempt to get argmin of an empty sequence
#
# During handling of the above exception, another exception occurred:
#
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-39-8e84c93e9173> in <module>()
#       2 last_result = frames[0]
#       3 for i in trange(1000):
# ----> 4     otrabotanniy.append(find_pupple(frames[i]))
#
# <ipython-input-36-9c1bb4909d72> in find_pupple(raw_image)
#      30         return cv2.ellipse(raw_image,ellipses[np.argmin(loss)],(255,255,255),2)
#      31     except:
# ---> 32         return last_result
#
# UnboundLocalError: local variable 'last_result' referenced before assignment

# %%
cv2.adaptiveThreshold?

# %%
cv2.ellipse?
