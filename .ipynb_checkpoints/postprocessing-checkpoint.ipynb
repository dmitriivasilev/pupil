# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pupil_area = np.load('pupil_area.npy')
pupil_center = np.load('pupil_center.npy')

# %%
plt.figure(figsize=(20,10))
plt.plot(pupil_area)
plt.plot([x*10 for x,y in pupil_center])
plt.plot([y*10 for x,y in pupil_center])

# %%
plt.figure(figsize=(20,10))
plt.plot(pupil_area)
plt.figure(figsize=(20,10))
plt.plot(np.diff(pupil_area))

# %%
plt.hist(np.diff([x for x in pupil_area if abs(x)<5000]))
# Out:
# (array([  1.00000000e+01,   8.00000000e+00,   1.60000000e+01,
#           2.70000000e+01,   1.82390000e+04,   3.50000000e+01,
#           1.20000000e+01,   9.00000000e+00,   8.00000000e+00,
#           2.00000000e+00]),
#  array([-4129.7199764 , -3218.94863688, -2308.17729736, -1397.40595784,
#          -486.63461832,   424.1367212 ,  1334.90806072,  2245.67940024,
#          3156.45073976,  4067.22207928,  4977.9934188 ]),
#  <a list of 10 Patch objects>)

# %%
len([x for x in pupil_area if abs(x)>10000])/len(pupil_area)
# Out:
# 0.02891322418591203
