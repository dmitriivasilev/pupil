# %%
# %matplotlib inline
import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import time as t
print("OpenCV Version : %s " % cv2.__version__)
# Out:
# OpenCV Version : 3.4.0

# %%
#get image
raw_image = cv2.imread(
                       'eye.jpg',#location of the file 
                       0 # "0" flag to get grayscale representation
                      )

# %%
plt.imshow(raw_image)

# %%
#we end up with 780x780 array with values ranging from 0 to 255
print(raw_image.shape)
print(raw_image)
# Out:
# (580, 780)
# [[254 255 253 ..., 254 255 254]
#  [110 114 107 ..., 255 255 255]
#  [110 114 107 ..., 250 251 254]
#  ...,
#  [ 67  67  67 ..., 255 255 255]
#  [ 66  66  66 ..., 255 255 255]
#  [ 65  65  65 ..., 255 255 255]]

# %%
# thresholding the image with threshold 50
ret,thresh = cv2.threshold(raw_image,80,255,0)

# %%
plt.imshow(thresh) # threshholded image

# %%
#it is also simply an array
print(thresh.shape)
print(thresh)
# Out:
# (580, 780)
# [[255 255 255 ..., 255 255 255]
#  [255 255 255 ..., 255 255 255]
#  [255 255 255 ..., 255 255 255]
#  ...,
#  [  0   0   0 ..., 255 255 255]
#  [  0   0   0 ..., 255 255 255]
#  [  0   0   0 ..., 255 255 255]]

# %%
#we use opencv black-magic to find contours on the image
image, contours, hierarchy = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)

# %%
#we create another image with contours drawn
contour_image = cv2.drawContours(raw_image.copy(), contours, -1, (255,255,255), 3)
# a small nuanse, draw contour destroys original image for some reason
#solution: use .copy method to perform the operation on copy of an image 
plt.imshow(contour_image)

# %%
#you guessed what is that
print(contour_image.shape)
print(contour_image)
# Out:
# (580, 780)
# [[255 255 255 ..., 255 255 255]
#  [255 255 255 ..., 255 255 255]
#  [255 255 255 ..., 255 255 255]
#  ...,
#  [ 67  67  67 ..., 255 255 255]
#  [ 66  66  66 ..., 255 255 255]
#  [ 65  65  65 ..., 255 255 255]]

# %%
#the thing we are interesteg now is contours which is a list of something. whatever
contours
# Out:
# [array([[[ 31, 579]]], dtype=int32), array([[[ 23, 578]],
#
#         [[ 22, 579]],
#
#         [[ 19, 579]],
#
#         [[ 28, 579]],
#
#         [[ 27, 578]]], dtype=int32), array([[[  0, 573]]], dtype=int32), array([[[ 24, 567]]], dtype=int32), array([[[ 17, 559]]], dtype=int32), array([[[ 42, 555]],
#
#         [[ 41, 556]],
#
#         [[ 42, 556]]], dtype=int32), array([[[  7, 555]],
#
#         [[  6, 556]],
#
#         [[  6, 557]],
#
#         [[ 15, 557]],
#
#         [[ 15, 556]],
#
#         [[  8, 556]]], dtype=int32), array([[[ 24, 550]],
#
#         [[ 25, 550]],
#
#         [[ 26, 551]],
#
#         [[ 25, 552]],
#
#         [[ 23, 552]],
#
#         [[ 21, 554]],
#
#         [[ 20, 554]],
#
#         [[ 21, 554]],
#
#         [[ 22, 555]],
#
#         [[ 23, 555]],
#
#         [[ 24, 556]],
#
#         [[ 23, 557]],
#
#         [[ 21, 557]],
#
#         [[ 22, 558]],
#
#         [[ 23, 557]],
#
#         [[ 29, 557]],
#
#         [[ 30, 558]],
#
#         [[ 31, 558]],
#
#         [[ 32, 557]],
#
#         [[ 36, 557]],
#
#         [[ 37, 556]],
#
#         [[ 38, 556]],
#
#         [[ 39, 557]],
#
#         [[ 39, 552]],
#
#         [[ 38, 551]],
#
#         [[ 36, 551]],
#
#         [[ 35, 550]],
#
#         [[ 33, 550]],
#
#         [[ 32, 551]],
#
#         [[ 31, 550]]], dtype=int32), array([[[ 36, 552]],
#
#         [[ 37, 551]],
#
#         [[ 38, 551]],
#
#         [[ 39, 552]],
#
#         [[ 38, 553]],
#
#         [[ 37, 553]]], dtype=int32), array([[[ 42, 548]],
#
#         [[ 42, 551]]], dtype=int32), array([[[ 65, 531]],
#
#         [[ 65, 532]],
#
#         [[ 66, 532]],
#
#         [[ 66, 531]]], dtype=int32), array([[[ 56, 530]],
#
#         [[ 56, 531]]], dtype=int32), array([[[ 76, 524]]], dtype=int32), array([[[ 56, 521]]], dtype=int32), array([[[ 55, 517]]], dtype=int32), array([[[ 85, 508]],
#
#         [[ 85, 509]]], dtype=int32), array([[[102, 504]],
#
#         [[103, 504]]], dtype=int32), array([[[245, 503]]], dtype=int32), array([[[ 87, 503]],
#
#         [[ 87, 504]],
#
#         [[ 86, 505]],
#
#         [[ 86, 506]],
#
#         [[ 88, 506]],
#
#         [[ 89, 507]],
#
#         [[ 88, 508]],
#
#         [[ 88, 509]],
#
#         [[ 87, 510]],
#
#         [[ 87, 511]],
#
#         [[ 87, 510]],
#
#         [[ 88, 509]],
#
#         [[ 89, 509]],
#
#         [[ 89, 508]],
#
#         [[ 90, 507]],
#
#         [[ 91, 507]],
#
#         [[ 92, 506]],
#
#         [[ 90, 506]],
#
#         [[ 89, 505]],
#
#         [[ 89, 504]],
#
#         [[ 90, 503]],
#
#         [[ 92, 503]],
#
#         [[ 89, 503]],
#
#         [[ 88, 504]]], dtype=int32), array([[[247, 501]],
#
#         [[247, 502]],
#
#         [[249, 502]],
#
#         [[248, 501]]], dtype=int32), array([[[245, 500]]], dtype=int32), array([[[237, 500]],
#
#         [[237, 503]]], dtype=int32), array([[[ 66, 499]],
#
#         [[ 64, 501]],
#
#         [[ 64, 503]],
#
#         [[ 65, 504]],
#
#         [[ 66, 504]],
#
#         [[ 67, 503]],
#
#         [[ 71, 503]],
#
#         [[ 71, 500]],
#
#         [[ 70, 500]],
#
#         [[ 69, 499]]], dtype=int32), array([[[219, 496]]], dtype=int32), array([[[205, 488]],
#
#         [[205, 489]]], dtype=int32), array([[[209, 487]],
#
#         [[211, 487]]], dtype=int32), array([[[151, 480]],
#
#         [[152, 480]]], dtype=int32), array([[[115, 479]],
#
#         [[116, 479]]], dtype=int32), array([[[537, 475]],
#
#         [[538, 475]]], dtype=int32), array([[[182, 475]],
#
#         [[183, 475]],
#
#         [[184, 476]],
#
#         [[185, 476]],
#
#         [[185, 475]]], dtype=int32), array([[[195, 472]],
#
#         [[194, 473]],
#
#         [[193, 473]],
#
#         [[192, 474]],
#
#         [[192, 478]],
#
#         [[193, 478]],
#
#         [[194, 479]],
#
#         [[195, 479]],
#
#         [[196, 480]],
#
#         [[197, 480]],
#
#         [[198, 481]],
#
#         [[199, 481]],
#
#         [[200, 482]],
#
#         [[200, 483]],
#
#         [[205, 483]],
#
#         [[205, 481]],
#
#         [[203, 479]],
#
#         [[203, 478]],
#
#         [[201, 476]],
#
#         [[200, 476]],
#
#         [[199, 475]],
#
#         [[199, 474]],
#
#         [[197, 474]]], dtype=int32), array([[[148, 469]]], dtype=int32), array([[[144, 469]]], dtype=int32), array([[[560, 468]],
#
#         [[561, 469]]], dtype=int32), array([[[566, 466]],
#
#         [[566, 467]]], dtype=int32), array([[[537, 466]],
#
#         [[537, 467]],
#
#         [[538, 468]],
#
#         [[539, 468]],
#
#         [[539, 466]]], dtype=int32), array([[[536, 463]]], dtype=int32), array([[[527, 461]]], dtype=int32), array([[[554, 459]],
#
#         [[554, 460]],
#
#         [[555, 459]]], dtype=int32), array([[[539, 459]],
#
#         [[539, 460]],
#
#         [[540, 461]],
#
#         [[540, 464]],
#
#         [[541, 464]],
#
#         [[541, 461]]], dtype=int32), array([[[493, 459]]], dtype=int32), array([[[489, 459]]], dtype=int32), array([[[183, 459]],
#
#         [[182, 460]],
#
#         [[180, 460]],
#
#         [[180, 461]],
#
#         [[179, 462]],
#
#         [[179, 463]],
#
#         [[180, 463]],
#
#         [[181, 464]],
#
#         [[181, 467]],
#
#         [[183, 467]],
#
#         [[184, 468]],
#
#         [[185, 468]],
#
#         [[187, 470]],
#
#         [[187, 471]],
#
#         [[189, 471]],
#
#         [[189, 465]],
#
#         [[187, 463]],
#
#         [[187, 462]],
#
#         [[186, 462]]], dtype=int32), array([[[533, 458]]], dtype=int32), array([[[552, 456]]], dtype=int32), array([[[543, 456]],
#
#         [[543, 457]],
#
#         [[544, 458]],
#
#         [[543, 459]],
#
#         [[543, 460]],
#
#         [[544, 461]],
#
#         [[551, 461]],
#
#         [[544, 461]],
#
#         [[543, 460]],
#
#         [[543, 459]],
#
#         [[544, 458]],
#
#         [[551, 458]],
#
#         [[544, 458]],
#
#         [[543, 457]]], dtype=int32), array([[[525, 455]],
#
#         [[525, 456]],
#
#         [[527, 456]],
#
#         [[528, 455]],
#
#         [[529, 455]],
#
#         [[530, 456]],
#
#         [[529, 455]]], dtype=int32), array([[[520, 455]]], dtype=int32), array([[[519, 452]],
#
#         [[519, 453]]], dtype=int32), array([[[512, 451]]], dtype=int32), array([[[521, 450]],
#
#         [[521, 451]],
#
#         [[522, 452]],
#
#         [[527, 452]],
#
#         [[527, 451]],
#
#         [[528, 450]],
#
#         [[527, 451]],
#
#         [[525, 451]],
#
#         [[524, 450]]], dtype=int32), array([[[516, 450]],
#
#         [[517, 450]]], dtype=int32), array([[[507, 450]],
#
#         [[508, 450]]], dtype=int32), array([[[499, 450]],
#
#         [[500, 450]]], dtype=int32), array([[[544, 449]],
#
#         [[544, 453]]], dtype=int32), array([[[503, 448]]], dtype=int32), array([[[496, 445]],
#
#         [[496, 446]],
#
#         [[495, 447]],
#
#         [[491, 447]],
#
#         [[495, 447]],
#
#         [[496, 448]],
#
#         [[496, 449]],
#
#         [[497, 449]],
#
#         [[497, 448]],
#
#         [[496, 448]],
#
#         [[495, 447]],
#
#         [[496, 446]],
#
#         [[497, 446]],
#
#         [[498, 445]]], dtype=int32), array([[[529, 442]],
#
#         [[529, 443]],
#
#         [[530, 444]],
#
#         [[532, 444]],
#
#         [[533, 443]],
#
#         [[532, 443]],
#
#         [[531, 442]]], dtype=int32), array([[[527, 442]],
#
#         [[527, 443]],
#
#         [[525, 445]],
#
#         [[524, 445]],
#
#         [[523, 444]],
#
#         [[522, 444]],
#
#         [[522, 445]],
#
#         [[523, 445]],
#
#         [[524, 446]],
#
#         [[525, 446]],
#
#         [[526, 445]],
#
#         [[527, 445]]], dtype=int32), array([[[141, 440]],
#
#         [[140, 441]],
#
#         [[140, 442]],
#
#         [[138, 444]],
#
#         [[138, 447]],
#
#         [[140, 449]],
#
#         [[140, 450]],
#
#         [[144, 454]],
#
#         [[144, 458]],
#
#         [[146, 460]],
#
#         [[146, 461]],
#
#         [[147, 462]],
#
#         [[151, 462]],
#
#         [[152, 463]],
#
#         [[150, 465]],
#
#         [[150, 466]],
#
#         [[151, 465]],
#
#         [[152, 466]],
#
#         [[152, 467]],
#
#         [[151, 468]],
#
#         [[150, 468]],
#
#         [[152, 470]],
#
#         [[155, 470]],
#
#         [[156, 471]],
#
#         [[159, 471]],
#
#         [[158, 471]],
#
#         [[157, 470]],
#
#         [[157, 469]],
#
#         [[158, 468]],
#
#         [[159, 468]],
#
#         [[160, 469]],
#
#         [[161, 469]],
#
#         [[161, 468]],
#
#         [[159, 466]],
#
#         [[161, 464]],
#
#         [[161, 462]],
#
#         [[159, 462]],
#
#         [[158, 461]],
#
#         [[160, 459]],
#
#         [[161, 459]],
#
#         [[161, 458]],
#
#         [[159, 456]],
#
#         [[159, 451]],
#
#         [[158, 450]],
#
#         [[158, 447]],
#
#         [[159, 446]],
#
#         [[159, 444]],
#
#         [[158, 443]],
#
#         [[158, 442]],
#
#         [[157, 442]],
#
#         [[156, 441]],
#
#         [[154, 441]],
#
#         [[153, 440]],
#
#         [[152, 440]],
#
#         [[151, 441]],
#
#         [[149, 441]],
#
#         [[148, 440]]], dtype=int32), array([[[481, 439]],
#
#         [[487, 439]]], dtype=int32), array([[[479, 439]]], dtype=int32), array([[[530, 435]]], dtype=int32), array([[[478, 434]],
#
#         [[478, 435]],
#
#         [[479, 435]],
#
#         [[479, 434]]], dtype=int32), array([[[527, 433]]], dtype=int32), array([[[499, 430]],
#
#         [[501, 430]],
#
#         [[502, 431]],
#
#         [[503, 431]],
#
#         [[502, 431]],
#
#         [[501, 430]]], dtype=int32), array([[[490, 428]],
#
#         [[490, 430]],
#
#         [[489, 431]],
#
#         [[490, 430]]], dtype=int32), array([[[473, 422]],
#
#         [[474, 423]],
#
#         [[473, 424]],
#
#         [[468, 424]],
#
#         [[469, 425]],
#
#         [[473, 425]],
#
#         [[473, 424]],
#
#         [[474, 423]],
#
#         [[475, 423]],
#
#         [[474, 423]]], dtype=int32), array([[[460, 422]]], dtype=int32), array([[[456, 421]],
#
#         [[456, 424]]], dtype=int32), array([[[458, 419]],
#
#         [[459, 420]],
#
#         [[459, 419]]], dtype=int32), array([[[452, 419]],
#
#         [[452, 423]],
#
#         [[453, 423]],
#
#         [[454, 422]],
#
#         [[454, 419]]], dtype=int32), array([[[478, 418]],
#
#         [[479, 418]]], dtype=int32), array([[[473, 417]],
#
#         [[473, 418]],
#
#         [[474, 419]],
#
#         [[475, 419]]], dtype=int32), array([[[443, 416]],
#
#         [[445, 416]]], dtype=int32), array([[[478, 415]],
#
#         [[477, 416]],
#
#         [[478, 415]],
#
#         [[479, 415]]], dtype=int32), array([[[469, 415]],
#
#         [[471, 415]]], dtype=int32), array([[[460, 411]],
#
#         [[460, 412]],
#
#         [[459, 413]],
#
#         [[459, 414]],
#
#         [[458, 415]],
#
#         [[459, 415]],
#
#         [[460, 416]],
#
#         [[462, 416]],
#
#         [[464, 414]],
#
#         [[465, 414]],
#
#         [[466, 413]],
#
#         [[465, 412]],
#
#         [[463, 412]],
#
#         [[462, 413]]], dtype=int32), array([[[459, 414]],
#
#         [[460, 413]],
#
#         [[462, 413]],
#
#         [[463, 414]],
#
#         [[463, 415]],
#
#         [[462, 416]],
#
#         [[460, 416]],
#
#         [[459, 415]]], dtype=int32), array([[[451, 411]],
#
#         [[449, 413]],
#
#         [[449, 414]],
#
#         [[450, 415]],
#
#         [[449, 416]],
#
#         [[449, 417]],
#
#         [[450, 418]],
#
#         [[450, 416]],
#
#         [[452, 414]],
#
#         [[452, 411]]], dtype=int32), array([[[456, 409]],
#
#         [[456, 412]]], dtype=int32), array([[[405, 409]]], dtype=int32), array([[[420, 407]],
#
#         [[421, 407]]], dtype=int32), array([[[479, 406]],
#
#         [[479, 407]]], dtype=int32), array([[[470, 405]],
#
#         [[470, 406]],
#
#         [[471, 406]],
#
#         [[472, 407]],
#
#         [[471, 406]],
#
#         [[471, 405]]], dtype=int32), array([[[424, 403]]], dtype=int32), array([[[480, 402]],
#
#         [[480, 403]],
#
#         [[481, 402]]], dtype=int32), array([[[459, 401]],
#
#         [[459, 403]],
#
#         [[460, 402]],
#
#         [[460, 401]]], dtype=int32), array([[[424, 400]],
#
#         [[427, 400]]], dtype=int32), array([[[419, 399]],
#
#         [[420, 400]],
#
#         [[421, 400]],
#
#         [[420, 400]]], dtype=int32), array([[[457, 398]],
#
#         [[456, 399]],
#
#         [[457, 399]],
#
#         [[458, 398]]], dtype=int32), array([[[416, 396]],
#
#         [[418, 396]]], dtype=int32), array([[[421, 392]],
#
#         [[421, 394]],
#
#         [[422, 394]],
#
#         [[421, 393]],
#
#         [[422, 392]]], dtype=int32), array([[[415, 392]],
#
#         [[416, 393]],
#
#         [[418, 393]],
#
#         [[416, 393]]], dtype=int32), array([[[413, 386]],
#
#         [[415, 386]]], dtype=int32), array([[[440, 384]]], dtype=int32), array([[[406, 382]],
#
#         [[406, 383]]], dtype=int32), array([[[362, 375]]], dtype=int32), array([[[371, 372]],
#
#         [[373, 372]],
#
#         [[376, 375]],
#
#         [[375, 376]],
#
#         [[373, 376]],
#
#         [[375, 376]],
#
#         [[376, 375]],
#
#         [[375, 374]],
#
#         [[375, 373]],
#
#         [[374, 373]],
#
#         [[373, 372]]], dtype=int32), array([[[374, 369]],
#
#         [[374, 370]],
#
#         [[375, 370]],
#
#         [[377, 372]],
#
#         [[378, 372]],
#
#         [[378, 370]],
#
#         [[376, 370]],
#
#         [[375, 369]]], dtype=int32), array([[[368, 369]]], dtype=int32), array([[[359, 368]],
#
#         [[360, 368]]], dtype=int32), array([[[357, 368]],
#
#         [[357, 369]],
#
#         [[356, 370]],
#
#         [[356, 371]],
#
#         [[356, 370]],
#
#         [[357, 369]]], dtype=int32), array([[[372, 362]],
#
#         [[372, 363]],
#
#         [[371, 364]],
#
#         [[370, 364]],
#
#         [[369, 365]],
#
#         [[370, 366]],
#
#         [[371, 366]],
#
#         [[372, 367]],
#
#         [[371, 368]],
#
#         [[370, 368]],
#
#         [[371, 368]],
#
#         [[372, 367]],
#
#         [[375, 367]],
#
#         [[375, 365]],
#
#         [[373, 367]],
#
#         [[372, 367]],
#
#         [[371, 366]],
#
#         [[374, 363]],
#
#         [[374, 362]]], dtype=int32), array([[[359, 362]],
#
#         [[359, 363]]], dtype=int32), array([[[357, 360]]], dtype=int32), array([[[365, 359]]], dtype=int32), array([[[361, 352]],
#
#         [[362, 352]],
#
#         [[364, 354]],
#
#         [[364, 355]],
#
#         [[365, 355]],
#
#         [[366, 356]],
#
#         [[366, 357]],
#
#         [[369, 360]],
#
#         [[371, 360]],
#
#         [[369, 358]],
#
#         [[368, 358]],
#
#         [[367, 357]],
#
#         [[367, 356]],
#
#         [[366, 355]],
#
#         [[366, 354]],
#
#         [[365, 353]],
#
#         [[364, 353]],
#
#         [[363, 352]]], dtype=int32), array([[[350, 351]]], dtype=int32), array([[[345, 350]],
#
#         [[345, 351]],
#
#         [[346, 350]]], dtype=int32), array([[[351, 347]],
#
#         [[351, 348]]], dtype=int32), array([[[105, 346]],
#
#         [[106, 346]],
#
#         [[107, 347]],
#
#         [[107, 346]]], dtype=int32), array([[[349, 344]],
#
#         [[348, 345]],
#
#         [[347, 345]],
#
#         [[348, 345]],
#
#         [[349, 344]],
#
#         [[351, 344]],
#
#         [[352, 345]],
#
#         [[354, 345]],
#
#         [[355, 344]]], dtype=int32), array([[[325, 343]],
#
#         [[326, 343]]], dtype=int32), array([[[320, 343]]], dtype=int32), array([[[104, 343]]], dtype=int32), array([[[341, 341]],
#
#         [[342, 341]],
#
#         [[343, 342]],
#
#         [[347, 342]],
#
#         [[346, 342]],
#
#         [[345, 341]],
#
#         [[344, 342]],
#
#         [[343, 341]]], dtype=int32), array([[[344, 339]]], dtype=int32), array([[[316, 339]],
#
#         [[316, 340]]], dtype=int32), array([[[348, 338]],
#
#         [[348, 339]],
#
#         [[349, 339]],
#
#         [[349, 338]]], dtype=int32), array([[[320, 338]],
#
#         [[319, 339]],
#
#         [[319, 340]],
#
#         [[318, 341]],
#
#         [[318, 342]],
#
#         [[316, 344]],
#
#         [[315, 344]],
#
#         [[314, 343]],
#
#         [[314, 342]],
#
#         [[313, 342]],
#
#         [[312, 341]],
#
#         [[312, 340]],
#
#         [[312, 342]],
#
#         [[313, 343]],
#
#         [[313, 344]],
#
#         [[312, 345]],
#
#         [[312, 346]],
#
#         [[314, 344]],
#
#         [[316, 344]],
#
#         [[320, 340]],
#
#         [[323, 340]],
#
#         [[324, 339]],
#
#         [[325, 339]],
#
#         [[321, 339]]], dtype=int32), array([[[ 99, 337]],
#
#         [[ 99, 338]],
#
#         [[102, 338]],
#
#         [[101, 338]],
#
#         [[100, 337]]], dtype=int32), array([[[327, 336]]], dtype=int32), array([[[313, 336]]], dtype=int32), array([[[345, 335]],
#
#         [[345, 336]],
#
#         [[347, 336]],
#
#         [[347, 335]]], dtype=int32), array([[[318, 335]],
#
#         [[318, 336]]], dtype=int32), array([[[316, 335]]], dtype=int32), array([[[323, 334]],
#
#         [[322, 335]],
#
#         [[325, 335]],
#
#         [[324, 335]]], dtype=int32), array([[[320, 332]]], dtype=int32), array([[[317, 331]]], dtype=int32), array([[[328, 330]],
#
#         [[328, 331]],
#
#         [[329, 331]],
#
#         [[329, 330]]], dtype=int32), array([[[319, 330]]], dtype=int32), array([[[  0, 323]],
#
#         [[  0, 330]],
#
#         [[  0, 328]],
#
#         [[  1, 327]],
#
#         [[  1, 326]],
#
#         [[  2, 325]],
#
#         [[  3, 325]],
#
#         [[  3, 324]],
#
#         [[  2, 323]]], dtype=int32), array([[[324, 320]],
#
#         [[324, 321]]], dtype=int32), array([[[ 75, 319]]], dtype=int32), array([[[304, 316]],
#
#         [[305, 316]]], dtype=int32), array([[[295, 315]]], dtype=int32), array([[[286, 297]]], dtype=int32), array([[[281, 297]],
#
#         [[281, 298]]], dtype=int32), array([[[288, 296]]], dtype=int32), array([[[281, 295]]], dtype=int32), array([[[  0, 295]]], dtype=int32), array([[[287, 293]]], dtype=int32), array([[[111, 293]]], dtype=int32), array([[[  6, 293]],
#
#         [[  6, 295]],
#
#         [[  5, 296]],
#
#         [[  4, 295]],
#
#         [[  4, 296]],
#
#         [[  7, 299]],
#
#         [[  8, 298]],
#
#         [[  9, 298]],
#
#         [[ 10, 299]],
#
#         [[ 10, 300]],
#
#         [[ 12, 300]],
#
#         [[ 11, 299]],
#
#         [[ 10, 299]],
#
#         [[  9, 298]],
#
#         [[ 10, 297]],
#
#         [[ 11, 297]],
#
#         [[ 12, 296]],
#
#         [[ 13, 296]],
#
#         [[ 10, 296]],
#
#         [[  8, 294]],
#
#         [[  8, 295]],
#
#         [[  7, 296]],
#
#         [[  6, 295]]], dtype=int32), array([[[ 11, 292]],
#
#         [[ 11, 293]]], dtype=int32), array([[[  2, 292]],
#
#         [[  2, 295]]], dtype=int32), array([[[279, 291]]], dtype=int32), array([[[ 16, 290]]], dtype=int32), array([[[  1, 290]]], dtype=int32), array([[[  3, 289]],
#
#         [[  3, 290]]], dtype=int32), array([[[288, 288]]], dtype=int32), array([[[272, 288]],
#
#         [[272, 289]]], dtype=int32), array([[[  5, 288]],
#
#         [[  5, 289]]], dtype=int32), array([[[290, 287]],
#
#         [[291, 287]],
#
#         [[292, 288]],
#
#         [[291, 287]]], dtype=int32), array([[[ 24, 287]]], dtype=int32), array([[[ 20, 287]]], dtype=int32), array([[[275, 284]],
#
#         [[275, 287]]], dtype=int32), array([[[290, 283]],
#
#         [[291, 283]]], dtype=int32), array([[[114, 281]],
#
#         [[115, 281]]], dtype=int32), array([[[ 98, 278]],
#
#         [[ 97, 279]],
#
#         [[ 95, 279]],
#
#         [[ 95, 280]],
#
#         [[ 94, 281]],
#
#         [[ 94, 282]],
#
#         [[ 95, 283]],
#
#         [[ 95, 284]],
#
#         [[ 94, 285]],
#
#         [[ 94, 286]],
#
#         [[ 96, 288]],
#
#         [[ 97, 288]],
#
#         [[ 98, 287]],
#
#         [[101, 287]],
#
#         [[101, 282]],
#
#         [[100, 281]],
#
#         [[100, 279]],
#
#         [[ 99, 278]]], dtype=int32), array([[[ 95, 287]],
#
#         [[ 96, 286]],
#
#         [[ 97, 287]],
#
#         [[ 96, 288]]], dtype=int32), array([[[ 88, 274]]], dtype=int32), array([[[ 99, 273]]], dtype=int32), array([[[137, 272]],
#
#         [[138, 272]],
#
#         [[139, 273]],
#
#         [[139, 274]],
#
#         [[137, 276]],
#
#         [[138, 277]],
#
#         [[141, 274]],
#
#         [[141, 273]],
#
#         [[140, 273]],
#
#         [[139, 272]]], dtype=int32), array([[[261, 271]],
#
#         [[260, 272]],
#
#         [[261, 272]]], dtype=int32), array([[[ 23, 269]]], dtype=int32), array([[[ 96, 267]],
#
#         [[ 96, 268]],
#
#         [[ 95, 269]],
#
#         [[ 93, 269]],
#
#         [[ 92, 270]],
#
#         [[ 91, 270]],
#
#         [[ 92, 270]],
#
#         [[ 93, 271]],
#
#         [[ 93, 272]],
#
#         [[ 95, 272]],
#
#         [[ 95, 270]],
#
#         [[ 96, 269]],
#
#         [[ 98, 271]],
#
#         [[100, 271]],
#
#         [[100, 268]],
#
#         [[ 99, 268]],
#
#         [[ 98, 267]]], dtype=int32), array([[[262, 266]],
#
#         [[262, 267]],
#
#         [[263, 267]],
#
#         [[263, 266]]], dtype=int32), array([[[  0, 266]],
#
#         [[  0, 267]],
#
#         [[  1, 267]]], dtype=int32), array([[[ 88, 265]],
#
#         [[ 87, 266]],
#
#         [[ 86, 266]],
#
#         [[ 88, 266]]], dtype=int32), array([[[ 21, 265]],
#
#         [[ 20, 266]],
#
#         [[ 21, 265]],
#
#         [[ 23, 267]],
#
#         [[ 23, 265]]], dtype=int32), array([[[134, 264]],
#
#         [[135, 264]]], dtype=int32), array([[[282, 263]]], dtype=int32), array([[[262, 263]],
#
#         [[263, 263]]], dtype=int32), array([[[ 93, 263]]], dtype=int32), array([[[ 86, 263]],
#
#         [[ 87, 263]]], dtype=int32), array([[[120, 262]]], dtype=int32), array([[[ 98, 262]],
#
#         [[ 98, 263]],
#
#         [[101, 263]],
#
#         [[ 99, 263]]], dtype=int32), array([[[ 23, 262]],
#
#         [[ 23, 263]],
#
#         [[ 24, 263]]], dtype=int32), array([[[111, 260]],
#
#         [[111, 261]]], dtype=int32), array([[[ 95, 260]],
#
#         [[ 96, 261]]], dtype=int32), array([[[ 42, 259]],
#
#         [[ 44, 259]]], dtype=int32), array([[[127, 258]]], dtype=int32), array([[[120, 257]],
#
#         [[121, 257]]], dtype=int32), array([[[108, 256]],
#
#         [[109, 256]]], dtype=int32), array([[[ 32, 256]],
#
#         [[ 33, 256]]], dtype=int32), array([[[265, 255]],
#
#         [[266, 255]]], dtype=int32), array([[[103, 255]]], dtype=int32), array([[[255, 252]]], dtype=int32), array([[[112, 252]],
#
#         [[112, 254]],
#
#         [[113, 255]],
#
#         [[114, 255]],
#
#         [[114, 253]],
#
#         [[113, 252]]], dtype=int32), array([[[117, 249]],
#
#         [[117, 252]],
#
#         [[118, 252]],
#
#         [[118, 251]],
#
#         [[119, 250]],
#
#         [[118, 249]]], dtype=int32), array([[[ 18, 249]],
#
#         [[ 15, 252]],
#
#         [[ 15, 253]],
#
#         [[ 16, 254]],
#
#         [[ 16, 257]],
#
#         [[ 15, 258]],
#
#         [[ 14, 258]],
#
#         [[ 13, 259]],
#
#         [[ 12, 258]],
#
#         [[ 12, 256]],
#
#         [[ 12, 261]],
#
#         [[ 11, 262]],
#
#         [[ 10, 262]],
#
#         [[  9, 263]],
#
#         [[  8, 263]],
#
#         [[  9, 264]],
#
#         [[  9, 268]],
#
#         [[  7, 270]],
#
#         [[  8, 271]],
#
#         [[  8, 272]],
#
#         [[ 11, 272]],
#
#         [[ 11, 271]],
#
#         [[ 12, 270]],
#
#         [[ 14, 270]],
#
#         [[ 17, 267]],
#
#         [[ 17, 265]],
#
#         [[ 18, 264]],
#
#         [[ 17, 263]],
#
#         [[ 17, 261]],
#
#         [[ 16, 260]],
#
#         [[ 16, 256]],
#
#         [[ 17, 255]],
#
#         [[ 19, 255]],
#
#         [[ 20, 256]],
#
#         [[ 20, 253]],
#
#         [[ 21, 252]],
#
#         [[ 21, 250]],
#
#         [[ 20, 249]]], dtype=int32), array([[[254, 248]],
#
#         [[255, 248]]], dtype=int32), array([[[120, 248]]], dtype=int32), array([[[ 32, 248]],
#
#         [[ 31, 249]],
#
#         [[ 31, 250]],
#
#         [[ 32, 251]],
#
#         [[ 32, 253]],
#
#         [[ 33, 252]],
#
#         [[ 31, 250]],
#
#         [[ 31, 249]]], dtype=int32), array([[[276, 247]],
#
#         [[278, 247]]], dtype=int32), array([[[261, 247]],
#
#         [[262, 247]]], dtype=int32), array([[[258, 247]]], dtype=int32), array([[[154, 247]]], dtype=int32), array([[[146, 247]],
#
#         [[147, 247]]], dtype=int32), array([[[114, 247]],
#
#         [[114, 248]],
#
#         [[115, 247]]], dtype=int32), array([[[ 47, 247]],
#
#         [[ 50, 247]]], dtype=int32), array([[[ 17, 247]],
#
#         [[ 18, 247]]], dtype=int32), array([[[268, 246]],
#
#         [[269, 246]]], dtype=int32), array([[[282, 245]],
#
#         [[283, 246]],
#
#         [[283, 247]],
#
#         [[284, 246]],
#
#         [[283, 245]]], dtype=int32), array([[[272, 245]]], dtype=int32), array([[[261, 245]]], dtype=int32), array([[[254, 245]],
#
#         [[254, 246]]], dtype=int32), array([[[287, 244]],
#
#         [[287, 246]],
#
#         [[288, 247]],
#
#         [[288, 248]],
#
#         [[288, 244]]], dtype=int32), array([[[114, 244]],
#
#         [[115, 244]]], dtype=int32), array([[[ 48, 244]]], dtype=int32), array([[[ 22, 244]],
#
#         [[ 22, 246]],
#
#         [[ 23, 247]],
#
#         [[ 25, 247]],
#
#         [[ 24, 247]],
#
#         [[ 23, 246]],
#
#         [[ 23, 245]],
#
#         [[ 24, 244]],
#
#         [[ 25, 244]]], dtype=int32), array([[[  5, 244]],
#
#         [[  4, 245]],
#
#         [[  3, 245]],
#
#         [[  2, 246]],
#
#         [[  1, 246]],
#
#         [[  0, 247]],
#
#         [[  0, 253]],
#
#         [[  3, 250]],
#
#         [[  4, 250]],
#
#         [[  6, 248]],
#
#         [[  7, 248]],
#
#         [[  8, 247]],
#
#         [[  8, 246]],
#
#         [[  9, 245]],
#
#         [[  9, 244]],
#
#         [[  8, 245]],
#
#         [[  7, 244]]], dtype=int32), array([[[275, 243]],
#
#         [[274, 244]],
#
#         [[276, 244]],
#
#         [[277, 245]],
#
#         [[279, 245]],
#
#         [[278, 244]],
#
#         [[277, 244]],
#
#         [[276, 243]]], dtype=int32), array([[[151, 241]]], dtype=int32), array([[[144, 241]],
#
#         [[144, 242]],
#
#         [[145, 241]]], dtype=int32), array([[[ 31, 241]]], dtype=int32), array([[[266, 240]],
#
#         [[265, 241]],
#
#         [[266, 241]],
#
#         [[268, 243]],
#
#         [[270, 243]],
#
#         [[270, 242]],
#
#         [[267, 242]],
#
#         [[266, 241]]], dtype=int32), array([[[254, 240]]], dtype=int32), array([[[156, 240]],
#
#         [[155, 241]],
#
#         [[154, 241]],
#
#         [[153, 242]],
#
#         [[153, 243]],
#
#         [[155, 243]],
#
#         [[156, 242]],
#
#         [[156, 241]],
#
#         [[157, 240]]], dtype=int32), array([[[128, 240]],
#
#         [[128, 241]],
#
#         [[129, 242]],
#
#         [[129, 241]],
#
#         [[130, 240]],
#
#         [[129, 241]]], dtype=int32), array([[[ 47, 240]]], dtype=int32), array([[[ 64, 239]],
#
#         [[ 65, 239]]], dtype=int32), array([[[ 51, 239]],
#
#         [[ 51, 240]],
#
#         [[ 50, 241]],
#
#         [[ 52, 241]],
#
#         [[ 53, 242]],
#
#         [[ 53, 243]],
#
#         [[ 52, 244]],
#
#         [[ 51, 244]],
#
#         [[ 52, 245]],
#
#         [[ 53, 244]],
#
#         [[ 53, 243]],
#
#         [[ 54, 242]],
#
#         [[ 53, 242]],
#
#         [[ 51, 240]],
#
#         [[ 52, 239]]], dtype=int32), array([[[256, 236]],
#
#         [[255, 237]],
#
#         [[253, 237]],
#
#         [[258, 237]],
#
#         [[259, 238]],
#
#         [[260, 238]],
#
#         [[260, 237]],
#
#         [[259, 236]]], dtype=int32), array([[[111, 236]]], dtype=int32), array([[[ 24, 236]],
#
#         [[ 24, 240]],
#
#         [[ 25, 240]],
#
#         [[ 26, 241]],
#
#         [[ 27, 241]],
#
#         [[ 27, 240]],
#
#         [[ 28, 239]],
#
#         [[ 28, 238]],
#
#         [[ 27, 238]],
#
#         [[ 27, 239]],
#
#         [[ 26, 240]],
#
#         [[ 25, 240]],
#
#         [[ 24, 239]]], dtype=int32), array([[[129, 235]],
#
#         [[128, 236]],
#
#         [[128, 237]],
#
#         [[129, 237]]], dtype=int32), array([[[255, 233]],
#
#         [[255, 234]]], dtype=int32), array([[[135, 233]],
#
#         [[135, 235]]], dtype=int32), array([[[ 79, 232]],
#
#         [[ 79, 233]]], dtype=int32), array([[[ 74, 232]]], dtype=int32), array([[[ 55, 232]],
#
#         [[ 55, 233]],
#
#         [[ 54, 234]],
#
#         [[ 53, 234]],
#
#         [[ 53, 237]],
#
#         [[ 54, 236]],
#
#         [[ 54, 234]],
#
#         [[ 55, 233]]], dtype=int32), array([[[114, 231]],
#
#         [[116, 231]]], dtype=int32), array([[[ 50, 228]],
#
#         [[ 50, 229]],
#
#         [[ 51, 230]],
#
#         [[ 51, 233]],
#
#         [[ 51, 228]]], dtype=int32), array([[[116, 227]],
#
#         [[117, 228]],
#
#         [[119, 228]],
#
#         [[120, 229]],
#
#         [[120, 230]],
#
#         [[121, 230]],
#
#         [[122, 231]],
#
#         [[121, 232]],
#
#         [[120, 232]],
#
#         [[119, 233]],
#
#         [[118, 233]],
#
#         [[117, 234]],
#
#         [[116, 233]],
#
#         [[116, 235]],
#
#         [[115, 236]],
#
#         [[115, 240]],
#
#         [[117, 242]],
#
#         [[119, 242]],
#
#         [[120, 241]],
#
#         [[120, 240]],
#
#         [[121, 239]],
#
#         [[122, 239]],
#
#         [[123, 240]],
#
#         [[124, 240]],
#
#         [[125, 239]],
#
#         [[126, 239]],
#
#         [[126, 238]],
#
#         [[125, 237]],
#
#         [[125, 235]],
#
#         [[126, 234]],
#
#         [[125, 233]],
#
#         [[124, 234]],
#
#         [[123, 234]],
#
#         [[122, 233]],
#
#         [[122, 232]],
#
#         [[123, 231]],
#
#         [[127, 231]],
#
#         [[126, 231]],
#
#         [[125, 230]],
#
#         [[125, 228]],
#
#         [[126, 227]],
#
#         [[124, 227]],
#
#         [[123, 228]],
#
#         [[122, 228]],
#
#         [[121, 229]],
#
#         [[120, 229]],
#
#         [[118, 227]]], dtype=int32), array([[[122, 235]],
#
#         [[123, 234]],
#
#         [[125, 236]],
#
#         [[125, 239]],
#
#         [[124, 240]],
#
#         [[123, 239]],
#
#         [[123, 237]],
#
#         [[122, 236]]], dtype=int32), array([[[ 56, 225]],
#
#         [[ 56, 226]]], dtype=int32), array([[[ 11, 225]]], dtype=int32), array([[[149, 224]]], dtype=int32), array([[[ 23, 224]]], dtype=int32), array([[[ 15, 224]],
#
#         [[ 15, 227]],
#
#         [[ 16, 227]],
#
#         [[ 16, 226]],
#
#         [[ 15, 225]]], dtype=int32), array([[[  3, 224]],
#
#         [[  2, 225]],
#
#         [[  0, 225]],
#
#         [[  0, 226]],
#
#         [[  1, 226]],
#
#         [[  2, 225]],
#
#         [[  4, 225]],
#
#         [[  4, 224]]], dtype=int32), array([[[252, 223]]], dtype=int32), array([[[118, 223]],
#
#         [[119, 223]]], dtype=int32), array([[[  6, 223]],
#
#         [[  8, 223]]], dtype=int32), array([[[256, 222]],
#
#         [[256, 223]]], dtype=int32), array([[[259, 220]]], dtype=int32), array([[[ 23, 220]],
#
#         [[ 23, 221]]], dtype=int32), array([[[ 16, 219]]], dtype=int32), array([[[ 89, 216]],
#
#         [[ 88, 217]],
#
#         [[ 88, 218]],
#
#         [[ 89, 217]]], dtype=int32), array([[[ 32, 216]]], dtype=int32), array([[[ 64, 213]]], dtype=int32), array([[[ 60, 213]],
#
#         [[ 60, 215]]], dtype=int32), array([[[  8, 213]],
#
#         [[  8, 215]],
#
#         [[  7, 216]],
#
#         [[  7, 217]],
#
#         [[  7, 216]],
#
#         [[  8, 215]],
#
#         [[ 10, 215]]], dtype=int32), array([[[ 32, 212]],
#
#         [[ 32, 213]],
#
#         [[ 33, 213]],
#
#         [[ 34, 212]]], dtype=int32), array([[[  8, 211]],
#
#         [[  9, 211]]], dtype=int32), array([[[ 24, 209]],
#
#         [[ 24, 214]],
#
#         [[ 25, 215]],
#
#         [[ 23, 217]],
#
#         [[ 21, 217]],
#
#         [[ 20, 218]],
#
#         [[ 23, 218]],
#
#         [[ 25, 216]],
#
#         [[ 26, 216]],
#
#         [[ 26, 214]],
#
#         [[ 25, 213]],
#
#         [[ 25, 212]],
#
#         [[ 24, 211]]], dtype=int32), array([[[  6, 206]],
#
#         [[  5, 207]],
#
#         [[  6, 207]]], dtype=int32), array([[[  1, 205]],
#
#         [[  1, 207]],
#
#         [[  2, 207]],
#
#         [[  2, 205]]], dtype=int32), array([[[180, 203]],
#
#         [[180, 207]],
#
#         [[179, 208]],
#
#         [[178, 207]],
#
#         [[178, 204]],
#
#         [[178, 207]],
#
#         [[179, 208]],
#
#         [[179, 209]],
#
#         [[180, 209]]], dtype=int32), array([[[ 56, 202]],
#
#         [[ 56, 203]],
#
#         [[ 57, 203]]], dtype=int32), array([[[214, 200]]], dtype=int32), array([[[208, 200]]], dtype=int32), array([[[  9, 200]],
#
#         [[  9, 203]],
#
#         [[  8, 204]],
#
#         [[  8, 207]],
#
#         [[  9, 207]],
#
#         [[  9, 204]],
#
#         [[ 10, 203]],
#
#         [[ 10, 200]]], dtype=int32), array([[[112, 199]]], dtype=int32), array([[[  7, 198]],
#
#         [[  7, 199]]], dtype=int32), array([[[ 54, 197]],
#
#         [[ 54, 198]],
#
#         [[ 55, 198]],
#
#         [[ 55, 197]]], dtype=int32), array([[[ 57, 196]],
#
#         [[ 58, 196]]], dtype=int32), array([[[ 18, 196]]], dtype=int32), array([[[210, 193]],
#
#         [[210, 194]]], dtype=int32), array([[[ 72, 193]],
#
#         [[ 73, 193]]], dtype=int32), array([[[213, 192]]], dtype=int32), array([[[ 66, 192]],
#
#         [[ 68, 192]]], dtype=int32), array([[[  5, 187]],
#
#         [[  5, 189]]], dtype=int32), array([[[ 72, 183]]], dtype=int32), array([[[ 20, 183]],
#
#         [[ 22, 183]],
#
#         [[ 23, 184]],
#
#         [[ 22, 183]]], dtype=int32), array([[[ 28, 181]],
#
#         [[ 30, 181]]], dtype=int32), array([[[223, 180]]], dtype=int32), array([[[ 32, 180]]], dtype=int32), array([[[  7, 180]],
#
#         [[  8, 181]],
#
#         [[  8, 180]]], dtype=int32), array([[[ 13, 176]],
#
#         [[ 13, 178]]], dtype=int32), array([[[ 10, 176]]], dtype=int32), array([[[228, 175]],
#
#         [[230, 175]]], dtype=int32), array([[[  3, 167]],
#
#         [[  1, 169]],
#
#         [[  0, 169]],
#
#         [[  0, 173]],
#
#         [[  3, 173]],
#
#         [[  4, 174]],
#
#         [[  4, 175]],
#
#         [[  3, 176]],
#
#         [[  2, 176]],
#
#         [[  2, 177]],
#
#         [[  4, 175]],
#
#         [[  6, 175]],
#
#         [[  7, 176]],
#
#         [[  6, 175]],
#
#         [[  6, 174]],
#
#         [[  5, 173]],
#
#         [[  6, 172]],
#
#         [[  6, 170]],
#
#         [[  5, 169]],
#
#         [[  3, 169]],
#
#         [[  2, 168]]], dtype=int32), array([[[ 18, 159]],
#
#         [[ 17, 160]],
#
#         [[ 18, 161]],
#
#         [[ 19, 161]],
#
#         [[ 19, 160]]], dtype=int32), array([[[ 24, 146]],
#
#         [[ 24, 147]],
#
#         [[ 25, 147]]], dtype=int32), array([[[ 28, 143]],
#
#         [[ 29, 143]]], dtype=int32), array([[[320, 126]],
#
#         [[320, 127]]], dtype=int32), array([[[  1, 112]],
#
#         [[  1, 114]],
#
#         [[  0, 115]],
#
#         [[  0, 117]],
#
#         [[  0, 116]],
#
#         [[  1, 115]],
#
#         [[  1, 114]],
#
#         [[  2, 113]],
#
#         [[  2, 112]]], dtype=int32), array([[[  0, 110]]], dtype=int32), array([[[340, 107]],
#
#         [[340, 108]],
#
#         [[341, 108]],
#
#         [[341, 107]]], dtype=int32), array([[[  0,   0]],
#
#         [[  0,  88]],
#
#         [[  1,  89]],
#
#         ...,
#         [[ 75, 579]],
#
#         [[779, 579]],
#
#         [[779,   0]]], dtype=int32), array([[[ 55, 576]],
#
#         [[ 56, 575]],
#
#         [[ 59, 575]],
#
#         [[ 60, 576]],
#
#         [[ 58, 578]],
#
#         [[ 56, 578]],
#
#         [[ 55, 577]]], dtype=int32), array([[[ 46, 576]],
#
#         [[ 47, 575]],
#
#         [[ 48, 576]],
#
#         [[ 47, 577]]], dtype=int32), array([[[ 80, 575]],
#
#         [[ 81, 574]],
#
#         [[ 82, 575]],
#
#         [[ 81, 576]]], dtype=int32), array([[[ 34, 575]],
#
#         [[ 35, 574]],
#
#         [[ 36, 575]],
#
#         [[ 35, 576]]], dtype=int32), array([[[ 60, 570]],
#
#         [[ 61, 570]],
#
#         [[ 62, 571]],
#
#         [[ 65, 571]],
#
#         [[ 67, 573]],
#
#         [[ 65, 575]],
#
#         [[ 64, 575]],
#
#         [[ 63, 576]],
#
#         [[ 60, 576]],
#
#         [[ 59, 575]],
#
#         [[ 57, 575]],
#
#         [[ 56, 574]],
#
#         [[ 56, 573]],
#
#         [[ 57, 572]],
#
#         [[ 58, 572]]], dtype=int32), array([[[ 39, 570]],
#
#         [[ 40, 569]],
#
#         [[ 41, 570]],
#
#         [[ 41, 571]],
#
#         [[ 40, 572]],
#
#         [[ 39, 571]]], dtype=int32), array([[[ 51, 551]],
#
#         [[ 52, 550]],
#
#         [[ 53, 550]],
#
#         [[ 54, 551]],
#
#         [[ 53, 552]],
#
#         [[ 52, 552]]], dtype=int32), array([[[ 70, 548]],
#
#         [[ 71, 547]],
#
#         [[ 72, 548]],
#
#         [[ 71, 549]]], dtype=int32), array([[[ 93, 543]],
#
#         [[ 94, 544]],
#
#         [[ 94, 545]],
#
#         [[ 93, 546]],
#
#         [[ 92, 546]],
#
#         [[ 91, 545]]], dtype=int32), array([[[ 87, 544]],
#
#         [[ 88, 543]],
#
#         [[ 89, 544]],
#
#         [[ 88, 545]]], dtype=int32), array([[[ 94, 542]],
#
#         [[ 95, 541]],
#
#         [[ 96, 542]],
#
#         [[ 95, 543]]], dtype=int32), array([[[ 89, 542]],
#
#         [[ 90, 541]],
#
#         [[ 91, 542]],
#
#         [[ 90, 543]]], dtype=int32), array([[[ 92, 540]],
#
#         [[ 93, 539]],
#
#         [[ 94, 540]],
#
#         [[ 94, 541]],
#
#         [[ 93, 542]],
#
#         [[ 92, 541]]], dtype=int32), array([[[ 89, 539]],
#
#         [[ 90, 538]],
#
#         [[ 91, 539]],
#
#         [[ 90, 540]]], dtype=int32), array([[[ 84, 537]],
#
#         [[ 85, 536]],
#
#         [[ 88, 536]],
#
#         [[ 89, 537]],
#
#         [[ 88, 538]],
#
#         [[ 85, 538]]], dtype=int32), array([[[ 86, 532]],
#
#         [[ 87, 531]],
#
#         [[ 88, 532]],
#
#         [[ 87, 533]]], dtype=int32), array([[[392, 529]],
#
#         [[393, 528]],
#
#         [[394, 529]],
#
#         [[393, 530]]], dtype=int32), array([[[ 88, 529]],
#
#         [[ 89, 528]],
#
#         [[ 90, 528]],
#
#         [[ 91, 529]],
#
#         [[ 90, 530]],
#
#         [[ 89, 530]]], dtype=int32), array([[[406, 528]],
#
#         [[407, 527]],
#
#         [[408, 528]],
#
#         [[407, 529]]], dtype=int32), array([[[ 86, 527]],
#
#         [[ 87, 526]],
#
#         [[ 88, 527]],
#
#         [[ 87, 528]]], dtype=int32), array([[[ 95, 523]],
#
#         [[ 96, 522]],
#
#         [[ 98, 522]],
#
#         [[ 99, 523]],
#
#         [[ 98, 524]],
#
#         [[ 96, 524]]], dtype=int32), array([[[ 99, 521]],
#
#         [[100, 520]],
#
#         [[101, 520]],
#
#         [[102, 521]],
#
#         [[101, 522]],
#
#         [[100, 522]]], dtype=int32), array([[[286, 520]],
#
#         [[287, 519]],
#
#         [[288, 520]],
#
#         [[287, 521]]], dtype=int32), array([[[281, 520]],
#
#         [[282, 519]],
#
#         [[283, 519]],
#
#         [[284, 520]],
#
#         [[283, 521]],
#
#         [[282, 521]]], dtype=int32), array([[[274, 519]],
#
#         [[275, 518]],
#
#         [[276, 519]],
#
#         [[275, 520]]], dtype=int32), array([[[278, 518]],
#
#         [[279, 517]],
#
#         [[280, 518]],
#
#         [[280, 519]],
#
#         [[279, 520]],
#
#         [[278, 519]]], dtype=int32), array([[[ 95, 512]],
#
#         [[ 96, 511]],
#
#         [[ 97, 511]],
#
#         [[ 98, 512]],
#
#         [[ 98, 513]],
#
#         [[ 97, 514]],
#
#         [[ 96, 514]],
#
#         [[ 95, 513]]], dtype=int32), array([[[ 90, 512]],
#
#         [[ 91, 511]],
#
#         [[ 93, 511]],
#
#         [[ 94, 512]],
#
#         [[ 94, 513]],
#
#         [[ 93, 514]],
#
#         [[ 92, 514]]], dtype=int32), array([[[ 94, 511]],
#
#         [[ 95, 510]],
#
#         [[ 96, 511]],
#
#         [[ 95, 512]]], dtype=int32), array([[[218, 502]],
#
#         [[219, 501]],
#
#         [[220, 501]],
#
#         [[221, 502]],
#
#         [[221, 503]],
#
#         [[220, 504]],
#
#         [[219, 504]],
#
#         [[218, 503]]], dtype=int32), array([[[179, 491]],
#
#         [[180, 490]],
#
#         [[181, 491]],
#
#         [[181, 492]],
#
#         [[180, 493]],
#
#         [[179, 492]]], dtype=int32), array([[[133, 491]],
#
#         [[134, 490]],
#
#         [[136, 490]],
#
#         [[137, 491]],
#
#         [[136, 492]],
#
#         [[134, 492]]], dtype=int32), array([[[151, 490]],
#
#         [[152, 489]],
#
#         [[153, 490]],
#
#         [[152, 491]]], dtype=int32), array([[[164, 487]],
#
#         [[165, 486]],
#
#         [[167, 486]],
#
#         [[168, 487]],
#
#         [[168, 488]],
#
#         [[167, 489]],
#
#         [[166, 488]],
#
#         [[165, 488]]], dtype=int32), array([[[162, 487]],
#
#         [[163, 486]],
#
#         [[164, 487]],
#
#         [[163, 488]]], dtype=int32), array([[[159, 487]],
#
#         [[160, 486]],
#
#         [[161, 487]],
#
#         [[160, 488]]], dtype=int32), array([[[156, 487]],
#
#         [[157, 486]],
#
#         [[158, 487]],
#
#         [[157, 488]]], dtype=int32), array([[[143, 487]],
#
#         [[144, 486]],
#
#         [[145, 487]],
#
#         [[144, 488]]], dtype=int32), array([[[118, 487]],
#
#         [[119, 486]],
#
#         [[120, 486]],
#
#         [[121, 487]],
#
#         [[120, 488]],
#
#         [[119, 488]]], dtype=int32), array([[[147, 485]],
#
#         [[148, 484]],
#
#         [[149, 485]],
#
#         [[148, 486]]], dtype=int32), array([[[162, 480]],
#
#         [[163, 479]],
#
#         [[165, 481]],
#
#         [[165, 483]],
#
#         [[165, 480]],
#
#         [[166, 479]],
#
#         [[167, 480]],
#
#         [[167, 485]],
#
#         [[166, 486]],
#
#         [[165, 485]],
#
#         [[164, 485]],
#
#         [[163, 486]],
#
#         [[162, 485]]], dtype=int32), array([[[173, 475]],
#
#         [[174, 474]],
#
#         [[175, 474]],
#
#         [[176, 475]],
#
#         [[175, 476]],
#
#         [[174, 476]]], dtype=int32), array([[[161, 475]],
#
#         [[162, 474]],
#
#         [[163, 475]],
#
#         [[162, 476]]], dtype=int32), array([[[573, 462]],
#
#         [[574, 461]],
#
#         [[575, 462]],
#
#         [[574, 463]]], dtype=int32), array([[[574, 461]],
#
#         [[575, 460]],
#
#         [[576, 461]],
#
#         [[575, 462]]], dtype=int32), array([[[560, 461]],
#
#         [[561, 460]],
#
#         [[562, 460]],
#
#         [[563, 461]],
#
#         [[562, 462]],
#
#         [[561, 462]]], dtype=int32), array([[[581, 460]],
#
#         [[582, 459]],
#
#         [[583, 460]],
#
#         [[583, 462]],
#
#         [[582, 463]],
#
#         [[581, 462]]], dtype=int32), array([[[583, 459]],
#
#         [[584, 458]],
#
#         [[585, 458]],
#
#         [[586, 459]],
#
#         [[585, 460]],
#
#         [[584, 460]]], dtype=int32), array([[[564, 458]],
#
#         [[565, 457]],
#
#         [[566, 458]],
#
#         [[565, 459]]], dtype=int32), array([[[587, 457]],
#
#         [[588, 456]],
#
#         [[589, 457]],
#
#         [[588, 458]]], dtype=int32), array([[[559, 457]],
#
#         [[560, 456]],
#
#         [[562, 458]],
#
#         [[560, 460]],
#
#         [[559, 459]]], dtype=int32), array([[[581, 456]],
#
#         [[582, 455]],
#
#         [[583, 456]],
#
#         [[582, 457]]], dtype=int32), array([[[566, 456]],
#
#         [[567, 455]],
#
#         [[568, 455]],
#
#         [[569, 456]],
#
#         [[568, 457]],
#
#         [[567, 457]]], dtype=int32), array([[[595, 455]],
#
#         [[596, 454]],
#
#         [[597, 454]],
#
#         [[598, 455]],
#
#         [[597, 456]],
#
#         [[596, 456]]], dtype=int32), array([[[603, 454]],
#
#         [[604, 453]],
#
#         [[605, 454]],
#
#         [[604, 455]]], dtype=int32), array([[[557, 453]],
#
#         [[558, 452]],
#
#         [[561, 452]],
#
#         [[562, 453]],
#
#         [[561, 454]],
#
#         [[560, 454]],
#
#         [[559, 455]]], dtype=int32), array([[[567, 451]],
#
#         [[568, 451]],
#
#         [[569, 452]],
#
#         [[567, 454]],
#
#         [[566, 454]],
#
#         [[565, 453]]], dtype=int32), array([[[551, 450]],
#
#         [[552, 449]],
#
#         [[553, 450]],
#
#         [[552, 451]]], dtype=int32), array([[[577, 448]],
#
#         [[578, 447]],
#
#         [[579, 448]],
#
#         [[578, 449]]], dtype=int32), array([[[569, 448]],
#
#         [[570, 447]],
#
#         [[571, 448]],
#
#         [[571, 455]],
#
#         [[570, 456]],
#
#         [[569, 455]]], dtype=int32), array([[[567, 447]],
#
#         [[568, 448]],
#
#         [[568, 449]],
#
#         [[567, 450]],
#
#         [[566, 450]],
#
#         [[565, 449]]], dtype=int32), array([[[548, 447]],
#
#         [[549, 446]],
#
#         [[550, 447]],
#
#         [[549, 448]]], dtype=int32), array([[[534, 447]],
#
#         [[535, 446]],
#
#         [[537, 446]],
#
#         [[538, 447]],
#
#         [[538, 448]],
#
#         [[537, 449]],
#
#         [[536, 449]]], dtype=int32), array([[[557, 446]],
#
#         [[558, 445]],
#
#         [[559, 445]],
#
#         [[561, 447]],
#
#         [[561, 449]],
#
#         [[560, 450]],
#
#         [[558, 450]],
#
#         [[557, 449]],
#
#         [[557, 448]],
#
#         [[558, 447]]], dtype=int32), array([[[559, 443]],
#
#         [[560, 442]],
#
#         [[561, 443]],
#
#         [[561, 444]],
#
#         [[560, 445]],
#
#         [[559, 444]]], dtype=int32), array([[[551, 442]],
#
#         [[552, 441]],
#
#         [[556, 441]],
#
#         [[558, 443]],
#
#         [[557, 444]],
#
#         [[552, 444]],
#
#         [[551, 443]]], dtype=int32), array([[[535, 441]],
#
#         [[536, 440]],
#
#         [[539, 440]],
#
#         [[540, 441]],
#
#         [[539, 442]],
#
#         [[537, 442]],
#
#         [[536, 443]],
#
#         [[535, 442]]], dtype=int32), array([[[509, 440]],
#
#         [[510, 439]],
#
#         [[511, 439]],
#
#         [[512, 440]],
#
#         [[512, 443]],
#
#         [[513, 444]],
#
#         [[513, 446]],
#
#         [[512, 447]],
#
#         [[511, 446]],
#
#         [[511, 445]],
#
#         [[510, 445]],
#
#         [[509, 444]],
#
#         [[509, 442]],
#
#         [[510, 441]]], dtype=int32), array([[[522, 438]],
#
#         [[523, 437]],
#
#         [[525, 437]],
#
#         [[526, 438]],
#
#         [[525, 439]],
#
#         [[523, 439]]], dtype=int32), array([[[585, 437]],
#
#         [[586, 436]],
#
#         [[587, 437]],
#
#         [[587, 438]],
#
#         [[586, 439]],
#
#         [[585, 438]]], dtype=int32), array([[[507, 437]],
#
#         [[508, 436]],
#
#         [[509, 437]],
#
#         [[509, 439]],
#
#         [[508, 440]],
#
#         [[507, 439]]], dtype=int32), array([[[522, 435]],
#
#         [[523, 434]],
#
#         [[525, 434]],
#
#         [[526, 435]],
#
#         [[526, 436]],
#
#         [[525, 437]],
#
#         [[523, 437]],
#
#         [[522, 436]]], dtype=int32), array([[[540, 434]],
#
#         [[541, 433]],
#
#         [[542, 434]],
#
#         [[541, 435]]], dtype=int32), array([[[521, 433]],
#
#         [[522, 432]],
#
#         [[523, 433]],
#
#         [[522, 434]]], dtype=int32), array([[[520, 432]],
#
#         [[521, 431]],
#
#         [[522, 432]],
#
#         [[521, 433]]], dtype=int32), array([[[543, 431]],
#
#         [[544, 430]],
#
#         [[545, 431]],
#
#         [[544, 432]]], dtype=int32), array([[[524, 430]],
#
#         [[525, 429]],
#
#         [[526, 430]],
#
#         [[525, 431]]], dtype=int32), array([[[535, 428]],
#
#         [[536, 427]],
#
#         [[537, 428]],
#
#         [[536, 429]]], dtype=int32), array([[[518, 428]],
#
#         [[519, 427]],
#
#         [[520, 428]],
#
#         [[520, 429]],
#
#         [[519, 430]],
#
#         [[518, 429]]], dtype=int32), array([[[539, 427]],
#
#         [[540, 426]],
#
#         [[541, 426]],
#
#         [[542, 427]],
#
#         [[541, 428]],
#
#         [[540, 428]]], dtype=int32), array([[[511, 427]],
#
#         [[512, 426]],
#
#         [[513, 427]],
#
#         [[513, 428]],
#
#         [[512, 429]],
#
#         [[511, 428]]], dtype=int32), array([[[520, 426]],
#
#         [[521, 425]],
#
#         [[522, 425]],
#
#         [[523, 426]],
#
#         [[523, 427]],
#
#         [[522, 428]],
#
#         [[521, 428]],
#
#         [[520, 427]]], dtype=int32), array([[[492, 426]],
#
#         [[493, 425]],
#
#         [[494, 426]],
#
#         [[493, 427]]], dtype=int32), array([[[495, 425]],
#
#         [[496, 424]],
#
#         [[497, 425]],
#
#         [[496, 426]]], dtype=int32), array([[[493, 424]],
#
#         [[494, 423]],
#
#         [[495, 424]],
#
#         [[495, 425]],
#
#         [[494, 426]],
#
#         [[493, 425]]], dtype=int32), array([[[490, 424]],
#
#         [[491, 423]],
#
#         [[492, 423]],
#
#         [[493, 424]],
#
#         [[493, 425]],
#
#         [[492, 426]]], dtype=int32), array([[[488, 424]],
#
#         [[489, 423]],
#
#         [[490, 424]],
#
#         [[490, 425]],
#
#         [[489, 426]],
#
#         [[488, 425]]], dtype=int32), array([[[511, 421]],
#
#         [[512, 420]],
#
#         [[514, 422]],
#
#         [[513, 423]],
#
#         [[512, 423]],
#
#         [[511, 422]]], dtype=int32), array([[[484, 421]],
#
#         [[485, 420]],
#
#         [[486, 420]],
#
#         [[487, 421]],
#
#         [[487, 423]],
#
#         [[486, 424]],
#
#         [[485, 424]],
#
#         [[484, 423]]], dtype=int32), array([[[524, 420]],
#
#         [[525, 419]],
#
#         [[526, 420]],
#
#         [[526, 421]],
#
#         [[525, 422]],
#
#         [[524, 421]]], dtype=int32), array([[[529, 419]],
#
#         [[530, 418]],
#
#         [[531, 419]],
#
#         [[531, 420]],
#
#         [[530, 421]],
#
#         [[529, 420]]], dtype=int32), array([[[511, 418]],
#
#         [[512, 417]],
#
#         [[513, 417]],
#
#         [[514, 418]],
#
#         [[517, 418]],
#
#         [[518, 419]],
#
#         [[518, 420]],
#
#         [[517, 421]],
#
#         [[515, 421]],
#
#         [[514, 420]],
#
#         [[512, 420]],
#
#         [[511, 419]]], dtype=int32), array([[[531, 417]],
#
#         [[532, 416]],
#
#         [[533, 417]],
#
#         [[532, 418]]], dtype=int32), array([[[501, 416]],
#
#         [[502, 415]],
#
#         [[503, 415]],
#
#         [[504, 416]],
#
#         [[503, 417]],
#
#         [[502, 417]]], dtype=int32), array([[[539, 415]],
#
#         [[540, 414]],
#
#         [[541, 414]],
#
#         [[542, 415]],
#
#         [[544, 415]],
#
#         [[546, 417]],
#
#         [[545, 418]],
#
#         [[541, 418]],
#
#         [[540, 419]],
#
#         [[539, 419]],
#
#         [[538, 418]],
#
#         [[538, 417]],
#
#         [[539, 416]]], dtype=int32), array([[[519, 415]],
#
#         [[520, 414]],
# ...
#
#         [[687, 172]],
#
#         [[686, 172]],
#
#         [[685, 171]]], dtype=int32), array([[[125, 169]],
#
#         [[126, 169]],
#
#         [[127, 170]],
#
#         [[127, 173]],
#
#         [[126, 174]],
#
#         [[124, 174]],
#
#         [[123, 173]],
#
#         [[123, 171]]], dtype=int32), array([[[ 48, 170]],
#
#         [[ 49, 169]],
#
#         [[ 50, 169]],
#
#         [[ 51, 170]],
#
#         [[ 51, 171]],
#
#         [[ 50, 172]],
#
#         [[ 49, 172]],
#
#         [[ 48, 171]]], dtype=int32), array([[[ 24, 169]],
#
#         [[ 25, 169]],
#
#         [[ 26, 170]],
#
#         [[ 24, 172]],
#
#         [[ 23, 172]],
#
#         [[ 22, 171]]], dtype=int32), array([[[685, 168]],
#
#         [[686, 167]],
#
#         [[687, 168]],
#
#         [[686, 169]]], dtype=int32), array([[[134, 168]],
#
#         [[135, 167]],
#
#         [[136, 168]],
#
#         [[135, 169]]], dtype=int32), array([[[126, 168]],
#
#         [[127, 167]],
#
#         [[128, 168]],
#
#         [[128, 169]],
#
#         [[127, 170]],
#
#         [[126, 169]]], dtype=int32), array([[[ 76, 168]],
#
#         [[ 77, 167]],
#
#         [[ 78, 168]],
#
#         [[ 78, 169]],
#
#         [[ 77, 170]],
#
#         [[ 76, 169]]], dtype=int32), array([[[ 68, 168]],
#
#         [[ 69, 167]],
#
#         [[ 70, 168]],
#
#         [[ 69, 169]]], dtype=int32), array([[[ 52, 168]],
#
#         [[ 53, 167]],
#
#         [[ 54, 168]],
#
#         [[ 53, 169]]], dtype=int32), array([[[ 63, 167]],
#
#         [[ 64, 166]],
#
#         [[ 65, 167]],
#
#         [[ 64, 168]]], dtype=int32), array([[[ 15, 167]],
#
#         [[ 16, 166]],
#
#         [[ 17, 167]],
#
#         [[ 16, 168]]], dtype=int32), array([[[682, 166]],
#
#         [[683, 165]],
#
#         [[685, 165]],
#
#         [[686, 166]],
#
#         [[685, 167]],
#
#         [[683, 167]]], dtype=int32), array([[[230, 165]],
#
#         [[231, 164]],
#
#         [[232, 165]],
#
#         [[231, 166]]], dtype=int32), array([[[ 81, 165]],
#
#         [[ 82, 164]],
#
#         [[ 83, 165]],
#
#         [[ 82, 166]]], dtype=int32), array([[[ 74, 165]],
#
#         [[ 75, 164]],
#
#         [[ 76, 164]],
#
#         [[ 77, 165]],
#
#         [[ 77, 167]],
#
#         [[ 76, 168]],
#
#         [[ 75, 168]],
#
#         [[ 74, 167]]], dtype=int32), array([[[ 70, 165]],
#
#         [[ 71, 164]],
#
#         [[ 72, 165]],
#
#         [[ 71, 166]]], dtype=int32), array([[[ 99, 164]],
#
#         [[100, 163]],
#
#         [[102, 165]],
#
#         [[101, 166]],
#
#         [[100, 166]],
#
#         [[ 99, 165]]], dtype=int32), array([[[ 69, 164]],
#
#         [[ 70, 163]],
#
#         [[ 71, 164]],
#
#         [[ 70, 165]]], dtype=int32), array([[[ 63, 164]],
#
#         [[ 64, 163]],
#
#         [[ 65, 164]],
#
#         [[ 65, 165]],
#
#         [[ 64, 166]],
#
#         [[ 63, 165]]], dtype=int32), array([[[ 68, 163]],
#
#         [[ 69, 162]],
#
#         [[ 70, 163]],
#
#         [[ 69, 164]]], dtype=int32), array([[[288, 162]],
#
#         [[289, 161]],
#
#         [[290, 162]],
#
#         [[290, 163]],
#
#         [[289, 164]],
#
#         [[288, 163]]], dtype=int32), array([[[ 46, 162]],
#
#         [[ 47, 161]],
#
#         [[ 48, 162]],
#
#         [[ 48, 163]],
#
#         [[ 47, 164]],
#
#         [[ 46, 163]]], dtype=int32), array([[[675, 161]],
#
#         [[676, 160]],
#
#         [[677, 161]],
#
#         [[676, 162]]], dtype=int32), array([[[ 69, 161]],
#
#         [[ 70, 160]],
#
#         [[ 71, 160]],
#
#         [[ 72, 161]],
#
#         [[ 72, 162]],
#
#         [[ 71, 163]]], dtype=int32), array([[[677, 160]],
#
#         [[678, 159]],
#
#         [[679, 160]],
#
#         [[678, 161]]], dtype=int32), array([[[673, 160]],
#
#         [[674, 159]],
#
#         [[675, 160]],
#
#         [[674, 161]]], dtype=int32), array([[[ 81, 160]],
#
#         [[ 82, 159]],
#
#         [[ 83, 159]],
#
#         [[ 84, 160]],
#
#         [[ 83, 161]],
#
#         [[ 82, 161]]], dtype=int32), array([[[ 52, 160]],
#
#         [[ 53, 159]],
#
#         [[ 54, 160]],
#
#         [[ 53, 161]]], dtype=int32), array([[[ 30, 159]],
#
#         [[ 32, 161]],
#
#         [[ 30, 163]],
#
#         [[ 29, 163]],
#
#         [[ 28, 162]],
#
#         [[ 28, 161]]], dtype=int32), array([[[138, 159]],
#
#         [[139, 158]],
#
#         [[140, 158]],
#
#         [[141, 159]],
#
#         [[140, 160]],
#
#         [[139, 160]]], dtype=int32), array([[[ 78, 158]],
#
#         [[ 79, 157]],
#
#         [[ 80, 158]],
#
#         [[ 80, 159]],
#
#         [[ 79, 160]],
#
#         [[ 78, 159]]], dtype=int32), array([[[ 36, 157]],
#
#         [[ 37, 156]],
#
#         [[ 38, 157]],
#
#         [[ 37, 158]]], dtype=int32), array([[[207, 156]],
#
#         [[208, 155]],
#
#         [[209, 156]],
#
#         [[208, 157]]], dtype=int32), array([[[666, 152]],
#
#         [[667, 151]],
#
#         [[668, 152]],
#
#         [[667, 153]]], dtype=int32), array([[[ 46, 152]],
#
#         [[ 47, 151]],
#
#         [[ 48, 152]],
#
#         [[ 47, 153]]], dtype=int32), array([[[ 31, 152]],
#
#         [[ 32, 151]],
#
#         [[ 35, 151]],
#
#         [[ 36, 152]],
#
#         [[ 37, 151]],
#
#         [[ 41, 151]],
#
#         [[ 43, 153]],
#
#         [[ 40, 156]],
#
#         [[ 39, 155]],
#
#         [[ 38, 156]],
#
#         [[ 37, 156]],
#
#         [[ 36, 155]],
#
#         [[ 32, 155]],
#
#         [[ 31, 154]]], dtype=int32), array([[[ 68, 151]],
#
#         [[ 69, 150]],
#
#         [[ 70, 151]],
#
#         [[ 69, 152]]], dtype=int32), array([[[ 41, 151]],
#
#         [[ 42, 150]],
#
#         [[ 44, 150]],
#
#         [[ 45, 151]],
#
#         [[ 44, 152]],
#
#         [[ 42, 152]]], dtype=int32), array([[[ 51, 149]],
#
#         [[ 52, 148]],
#
#         [[ 53, 149]],
#
#         [[ 52, 150]]], dtype=int32), array([[[ 17, 149]],
#
#         [[ 18, 148]],
#
#         [[ 19, 149]],
#
#         [[ 18, 150]]], dtype=int32), array([[[ 79, 148]],
#
#         [[ 80, 147]],
#
#         [[ 81, 148]],
#
#         [[ 80, 149]]], dtype=int32), array([[[ 31, 145]],
#
#         [[ 32, 144]],
#
#         [[ 33, 144]],
#
#         [[ 35, 146]],
#
#         [[ 35, 149]],
#
#         [[ 34, 150]],
#
#         [[ 33, 150]],
#
#         [[ 32, 151]],
#
#         [[ 31, 150]],
#
#         [[ 31, 149]],
#
#         [[ 32, 148]],
#
#         [[ 33, 148]],
#
#         [[ 33, 147]]], dtype=int32), array([[[ 18, 145]],
#
#         [[ 19, 144]],
#
#         [[ 20, 145]],
#
#         [[ 20, 146]],
#
#         [[ 19, 147]],
#
#         [[ 18, 146]]], dtype=int32), array([[[ 82, 144]],
#
#         [[ 83, 143]],
#
#         [[ 84, 144]],
#
#         [[ 83, 145]]], dtype=int32), array([[[ 35, 144]],
#
#         [[ 36, 143]],
#
#         [[ 37, 143]],
#
#         [[ 38, 144]],
#
#         [[ 37, 145]],
#
#         [[ 36, 145]]], dtype=int32), array([[[ 19, 144]],
#
#         [[ 20, 143]],
#
#         [[ 21, 144]],
#
#         [[ 20, 145]]], dtype=int32), array([[[264, 143]],
#
#         [[265, 142]],
#
#         [[266, 143]],
#
#         [[265, 144]]], dtype=int32), array([[[ 80, 143]],
#
#         [[ 81, 142]],
#
#         [[ 82, 143]],
#
#         [[ 82, 144]],
#
#         [[ 81, 145]],
#
#         [[ 80, 144]]], dtype=int32), array([[[ 34, 143]],
#
#         [[ 35, 142]],
#
#         [[ 36, 143]],
#
#         [[ 35, 144]]], dtype=int32), array([[[ 11, 142]],
#
#         [[ 12, 141]],
#
#         [[ 14, 143]],
#
#         [[ 13, 144]],
#
#         [[ 12, 144]],
#
#         [[ 11, 143]]], dtype=int32), array([[[ 41, 141]],
#
#         [[ 42, 140]],
#
#         [[ 43, 141]],
#
#         [[ 42, 142]]], dtype=int32), array([[[ 17, 141]],
#
#         [[ 18, 140]],
#
#         [[ 21, 140]],
#
#         [[ 22, 141]],
#
#         [[ 22, 142]],
#
#         [[ 21, 143]],
#
#         [[ 19, 143]],
#
#         [[ 19, 144]],
#
#         [[ 18, 145]],
#
#         [[ 17, 144]]], dtype=int32), array([[[ 31, 140]],
#
#         [[ 32, 139]],
#
#         [[ 34, 139]],
#
#         [[ 36, 141]],
#
#         [[ 34, 143]],
#
#         [[ 33, 142]],
#
#         [[ 32, 142]],
#
#         [[ 31, 141]]], dtype=int32), array([[[ 36, 138]],
#
#         [[ 37, 137]],
#
#         [[ 38, 138]],
#
#         [[ 38, 139]],
#
#         [[ 37, 140]],
#
#         [[ 36, 139]]], dtype=int32), array([[[311, 137]],
#
#         [[312, 136]],
#
#         [[313, 136]],
#
#         [[314, 137]],
#
#         [[313, 138]],
#
#         [[312, 138]]], dtype=int32), array([[[ 32, 137]],
#
#         [[ 33, 136]],
#
#         [[ 34, 136]],
#
#         [[ 35, 137]],
#
#         [[ 33, 139]],
#
#         [[ 32, 138]]], dtype=int32), array([[[ 50, 135]],
#
#         [[ 51, 134]],
#
#         [[ 52, 134]],
#
#         [[ 53, 135]],
#
#         [[ 52, 136]],
#
#         [[ 51, 136]]], dtype=int32), array([[[ 36, 135]],
#
#         [[ 37, 134]],
#
#         [[ 38, 135]],
#
#         [[ 37, 136]]], dtype=int32), array([[[318, 132]],
#
#         [[319, 131]],
#
#         [[320, 132]],
#
#         [[320, 133]],
#
#         [[319, 134]],
#
#         [[318, 133]]], dtype=int32), array([[[ 30, 122]],
#
#         [[ 31, 121]],
#
#         [[ 32, 122]],
#
#         [[ 32, 123]],
#
#         [[ 31, 124]],
#
#         [[ 30, 123]]], dtype=int32), array([[[ 17, 122]],
#
#         [[ 18, 121]],
#
#         [[ 19, 121]],
#
#         [[ 20, 122]],
#
#         [[ 19, 123]],
#
#         [[ 18, 123]]], dtype=int32), array([[[ 71, 120]],
#
#         [[ 72, 119]],
#
#         [[ 73, 120]],
#
#         [[ 72, 121]]], dtype=int32), array([[[ 31, 120]],
#
#         [[ 32, 119]],
#
#         [[ 33, 120]],
#
#         [[ 32, 121]]], dtype=int32), array([[[ 24, 120]],
#
#         [[ 25, 119]],
#
#         [[ 26, 119]],
#
#         [[ 27, 120]],
#
#         [[ 26, 121]],
#
#         [[ 25, 121]]], dtype=int32), array([[[ 20, 119]],
#
#         [[ 21, 118]],
#
#         [[ 22, 119]],
#
#         [[ 21, 120]]], dtype=int32), array([[[ 13, 119]],
#
#         [[ 14, 118]],
#
#         [[ 18, 118]],
#
#         [[ 19, 119]],
#
#         [[ 18, 120]],
#
#         [[ 17, 120]],
#
#         [[ 16, 121]],
#
#         [[ 16, 122]],
#
#         [[ 15, 123]],
#
#         [[ 14, 122]],
#
#         [[ 14, 120]]], dtype=int32), array([[[335, 117]],
#
#         [[336, 116]],
#
#         [[337, 117]],
#
#         [[336, 118]]], dtype=int32), array([[[336, 116]],
#
#         [[337, 115]],
#
#         [[338, 116]],
#
#         [[337, 117]]], dtype=int32), array([[[335, 115]],
#
#         [[336, 114]],
#
#         [[337, 115]],
#
#         [[336, 116]]], dtype=int32), array([[[336, 114]],
#
#         [[337, 113]],
#
#         [[338, 114]],
#
#         [[337, 115]]], dtype=int32), array([[[ 16, 113]],
#
#         [[ 17, 112]],
#
#         [[ 19, 114]],
#
#         [[ 18, 115]],
#
#         [[ 17, 115]],
#
#         [[ 16, 114]]], dtype=int32), array([[[337, 112]],
#
#         [[338, 111]],
#
#         [[339, 111]],
#
#         [[340, 112]],
#
#         [[340, 113]],
#
#         [[339, 114]]], dtype=int32), array([[[ 15, 112]],
#
#         [[ 16, 111]],
#
#         [[ 17, 112]],
#
#         [[ 16, 113]]], dtype=int32), array([[[ 22, 111]],
#
#         [[ 23, 110]],
#
#         [[ 24, 111]],
#
#         [[ 23, 112]]], dtype=int32), array([[[345, 109]],
#
#         [[346, 108]],
#
#         [[347, 109]],
#
#         [[346, 110]]], dtype=int32), array([[[346, 108]],
#
#         [[347, 107]],
#
#         [[348, 108]],
#
#         [[347, 109]]], dtype=int32), array([[[ 17, 107]],
#
#         [[ 18, 106]],
#
#         [[ 19, 106]],
#
#         [[ 20, 107]],
#
#         [[ 20, 108]],
#
#         [[ 19, 109]],
#
#         [[ 18, 109]],
#
#         [[ 17, 108]]], dtype=int32), array([[[ 11, 107]],
#
#         [[ 12, 106]],
#
#         [[ 13, 107]],
#
#         [[ 13, 109]],
#
#         [[ 14, 110]],
#
#         [[ 15, 109]],
#
#         [[ 16, 110]],
#
#         [[ 16, 111]],
#
#         [[ 15, 112]],
#
#         [[ 11, 112]],
#
#         [[ 10, 111]],
#
#         [[ 10, 110]],
#
#         [[ 11, 109]]], dtype=int32), array([[[ 15, 105]],
#
#         [[ 16, 106]],
#
#         [[ 16, 108]],
#
#         [[ 15, 109]],
#
#         [[ 14, 109]],
#
#         [[ 13, 108]],
#
#         [[ 13, 107]]], dtype=int32), array([[[ 30, 104]],
#
#         [[ 31, 103]],
#
#         [[ 32, 104]],
#
#         [[ 31, 105]]], dtype=int32), array([[[ 17, 104]],
#
#         [[ 18, 103]],
#
#         [[ 19, 103]],
#
#         [[ 20, 104]],
#
#         [[ 19, 105]],
#
#         [[ 18, 105]]], dtype=int32), array([[[  6, 104]],
#
#         [[  7, 103]],
#
#         [[  8, 104]],
#
#         [[  8, 105]],
#
#         [[  7, 106]],
#
#         [[  6, 105]]], dtype=int32), array([[[  3, 103]],
#
#         [[  4, 102]],
#
#         [[  5, 103]],
#
#         [[  4, 104]]], dtype=int32), array([[[  6, 102]],
#
#         [[  7, 101]],
#
#         [[  8, 102]],
#
#         [[  7, 103]]], dtype=int32), array([[[ 13, 100]],
#
#         [[ 14,  99]],
#
#         [[ 15,  99]],
#
#         [[ 16, 100]],
#
#         [[ 16, 101]],
#
#         [[ 18, 101]],
#
#         [[ 19, 100]],
#
#         [[ 20, 100]],
#
#         [[ 21, 101]],
#
#         [[ 21, 102]],
#
#         [[ 20, 103]],
#
#         [[ 15, 103]],
#
#         [[ 13, 101]]], dtype=int32), array([[[  2,  99]],
#
#         [[  3,  98]],
#
#         [[  4,  98]],
#
#         [[  5,  99]],
#
#         [[  4, 100]],
#
#         [[  3, 100]]], dtype=int32), array([[[ 6, 97]],
#
#         [[ 7, 96]],
#
#         [[ 8, 97]],
#
#         [[ 8, 98]],
#
#         [[ 7, 99]],
#
#         [[ 6, 98]]], dtype=int32), array([[[363,  96]],
#
#         [[364,  95]],
#
#         [[365,  95]],
#
#         [[366,  96]],
#
#         [[366,  97]],
#
#         [[365,  98]],
#
#         [[364,  98]],
#
#         [[363,  97]]], dtype=int32), array([[[ 9, 96]],
#
#         [[10, 95]],
#
#         [[11, 96]],
#
#         [[11, 98]],
#
#         [[10, 99]],
#
#         [[ 9, 98]]], dtype=int32), array([[[ 0, 96]],
#
#         [[ 1, 95]],
#
#         [[ 4, 95]],
#
#         [[ 5, 96]],
#
#         [[ 4, 97]],
#
#         [[ 1, 97]]], dtype=int32), array([[[ 4, 95]],
#
#         [[ 5, 94]],
#
#         [[ 6, 95]],
#
#         [[ 5, 96]]], dtype=int32), array([[[358,  93]],
#
#         [[359,  92]],
#
#         [[361,  94]],
#
#         [[361,  97]],
#
#         [[360,  98]],
#
#         [[358,  98]],
#
#         [[357,  99]],
#
#         [[357, 100]],
#
#         [[355, 102]],
#
#         [[352, 102]],
#
#         [[352, 103]],
#
#         [[351, 104]],
#
#         [[350, 104]],
#
#         [[348, 106]],
#
#         [[347, 106]],
#
#         [[346, 105]],
#
#         [[346, 104]],
#
#         [[345, 103]],
#
#         [[341, 103]],
#
#         [[340, 102]],
#
#         [[342, 100]],
#
#         [[343, 100]],
#
#         [[344,  99]],
#
#         [[346,  99]],
#
#         [[347, 100]],
#
#         [[349, 100]],
#
#         [[348, 100]],
#
#         [[347,  99]],
#
#         [[347,  98]],
#
#         [[348,  97]],
#
#         [[353,  97]],
#
#         [[354,  96]],
#
#         [[355,  96]],
#
#         [[356,  95]],
#
#         [[358,  95]],
#
#         [[359,  96]],
#
#         [[358,  95]]], dtype=int32), array([[[ 3, 92]],
#
#         [[ 4, 91]],
#
#         [[ 6, 91]],
#
#         [[ 7, 92]],
#
#         [[ 5, 94]],
#
#         [[ 4, 94]],
#
#         [[ 3, 93]]], dtype=int32), array([[[370,  89]],
#
#         [[371,  88]],
#
#         [[373,  88]],
#
#         [[374,  89]],
#
#         [[375,  89]],
#
#         [[376,  90]],
#
#         [[378,  90]],
#
#         [[379,  89]],
#
#         [[381,  89]],
#
#         [[382,  90]],
#
#         [[382,  91]],
#
#         [[381,  92]],
#
#         [[378,  92]],
#
#         [[377,  93]],
#
#         [[376,  93]],
#
#         [[375,  94]],
#
#         [[374,  94]],
#
#         [[372,  96]],
#
#         [[370,  96]],
#
#         [[369,  95]],
#
#         [[368,  95]],
#
#         [[367,  96]],
#
#         [[365,  94]],
#
#         [[364,  95]],
#
#         [[363,  95]],
#
#         [[362,  94]],
#
#         [[362,  93]],
#
#         [[363,  92]],
#
#         [[365,  92]],
#
#         [[368,  89]]], dtype=int32), array([[[ 4, 89]],
#
#         [[ 5, 88]],
#
#         [[ 6, 89]],
#
#         [[ 5, 90]]], dtype=int32), array([[[31, 88]],
#
#         [[32, 87]],
#
#         [[34, 87]],
#
#         [[35, 88]],
#
#         [[34, 89]],
#
#         [[32, 89]]], dtype=int32), array([[[ 9, 87]],
#
#         [[10, 86]],
#
#         [[11, 87]],
#
#         [[10, 88]]], dtype=int32), array([[[384,  85]],
#
#         [[385,  84]],
#
#         [[386,  85]],
#
#         [[386,  86]],
#
#         [[385,  87]],
#
#         [[384,  86]]], dtype=int32), array([[[ 3, 79]],
#
#         [[ 4, 78]],
#
#         [[ 5, 79]],
#
#         [[ 4, 80]]], dtype=int32), array([[[44, 60]],
#
#         [[45, 59]],
#
#         [[46, 60]],
#
#         [[45, 61]]], dtype=int32), array([[[46, 57]],
#
#         [[47, 56]],
#
#         [[48, 57]],
#
#         [[48, 58]],
#
#         [[47, 59]],
#
#         [[46, 58]]], dtype=int32)]

# %%
#we filter them by length 
# the line below is a list comprehention (google it)
#basicaly it creates another list taking elements from contours which have length < 1000 and > 200
filtered_contours = [cnt for cnt in contours if (len(cnt)<1000) and (len(cnt)>200)]

# %%
#we have 3 of them 
len(filtered_contours)
# Out:
# 0

# %%
plt.imshow(raw_image)

# %%
#lets draw them
filtered_contour_image = cv2.drawContours(raw_image, filtered_contours, -1, (255,255,255), 3)

plt.imshow(filtered_contour_image)

# %%
#we see that all the contoures are quite similar in size but differ in shape 
# the plan is to find one which is the most similar to ellipse

# %%
ellipses = [] # we create an empty list to fill later
for cnt in filtered_contours: # for each contour from out list
    try: # we try to apply ellipse fitting
        ellipses.append(cv2.fitEllipse(cnt)) #and add the result to list of ellipses
    except: # if not
        pass # whatever
#P.S.: remember, I didn't teach you to do that

# %%
#we have 3 contours
len(filtered_contours)
# Out:
# 0

# %%
# and 3 ellipses
len(ellipses)
# Out:
# 0

# %%
# it means that at least our thing didn't go completely wrong

# %%
for ellipse in ellipses:
    plt.figure()
    plt.imshow(cv2.ellipse(raw_image.copy(),ellipse,(255,255,255),2))

# %%
# we want to get the one which is the most similar to ellipse
# we introduse "loss" which is the difference in the are of fitted ellipse and contour 
# so if this loss id close to zero then the shape of contour is close to an ellipse
# which is completely wrong but it will work for now

loss = [] #emply list to fill the loss values
for ellipse,contour in zip(ellipses,filtered_contours): # for each ellipse and contours from our ellipses and contours 
                                                        # (google zip function)
    loss.append(abs((np.pi/4 * ellipse[1][0] * ellipse[1][1])-(cv2.contourArea(contour))))
#difference between ellipse area ^              and contour area        ^

# %%
loss # we have three values
# Out:
# []

# %%
#we draw argmin of loss (argmin returns the index of minimum values of array/list)
plt.imshow(cv2.ellipse(raw_image,ellipses[np.argmin(loss)],(255,255,255),2))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      56     try:
# ---> 57         return getattr(obj, method)(*args, **kwds)
#      58
#
# AttributeError: 'list' object has no attribute 'argmin'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-ccebe01bc7a3> in <module>()
#       1 #we draw argmin of loss (argmin returns the index of minimum values of array/list)
# ----> 2 plt.imshow(cv2.ellipse(raw_image,ellipses[np.argmin(loss)],(255,255,255),2))
#
# ~\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py in argmin(a, axis, out)
#    1017
#    1018     """
# -> 1019     return _wrapfunc(a, 'argmin', axis=axis, out=out)
#    1020
#    1021
#
# ~\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      65     # a downstream library like 'pandas'.
#      66     except (AttributeError, TypeError):
# ---> 67         return _wrapit(obj, method, *args, **kwds)
#      68
#      69
#
# ~\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py in _wrapit(obj, method, *args, **kwds)
#      45     except AttributeError:
#      46         wrap = None
# ---> 47     result = getattr(asarray(obj), method)(*args, **kwds)
#      48     if wrap:
#      49         if not isinstance(result, mu.ndarray):
#
# ValueError: attempt to get argmin of an empty sequence

# %%
#lets put everything together:

# %%
def find_pupple(filename):
    raw_image = cv2.imread(filename,0)
    
    ret,thresh = cv2.threshold(raw_image,50,255,0)
    image, contours, hierarchy = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
    contour_image = cv2.drawContours(raw_image.copy(), contours, -1, (255,255,255), 3)

    filtered_contours = [cnt for cnt in contours if (len(cnt)<1000) and (len(cnt)>200)]

    ellipses = [] 
    for cnt in filtered_contours: 
        try: 
            ellipses.append(cv2.fitEllipse(cnt)) 
        except: 
            pass 

        loss = [] 

    for ellipse,contour in zip(ellipses,filtered_contours): 
        loss.append(abs((np.pi/4 * ellipse[1][0] * ellipse[1][1])-(cv2.contourArea(contour))))
    

    return cv2.ellipse(raw_image,ellipses[np.argmin(loss)],(255,255,255),2)

# %%
plt.imshow(find_pupple('eye.jpg')) #does the same thing, try it on different images
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-29-4c8ac9c6986e> in <module>()
# ----> 1 plt.imshow(find_pupple('eye.jpg')) #does the same thing, try it on different images
#
# <ipython-input-28-3ced64a77d73> in find_pupple(filename)
#      21
#      22
# ---> 23     return cv2.ellipse(raw_image,ellipses[np.argmin(loss)],(255,255,255),2)
#
# UnboundLocalError: local variable 'loss' referenced before assignment

# %%
# %timeit find_pupple('eye.jpg') #~12 ms per frame on my machine, think whether its a good news or bad news
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-30-fc08448e95b9> in <module>()
# ----> 1 get_ipython().magic("timeit find_pupple('eye.jpg') #~12 ms per frame on my machine, think whether its a good news or bad news")
#
# ~\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in magic(self, arg_s)
#    2144         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2145         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2146         return self.run_line_magic(magic_name, magic_arg_s)
#    2147
#    2148     #-------------------------------------------------------------------------
#
# ~\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line)
#    2065                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2066             with self.builtin_trap:
# -> 2067                 result = fn(*args,**kwargs)
#    2068             return result
#    2069
#
# <decorator-gen-62> in timeit(self, line, cell)
#
# ~\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\Anaconda3\lib\site-packages\IPython\core\magics\execution.py in timeit(self, line, cell)
#    1078             for index in range(0, 10):
#    1079                 number = 10 ** index
# -> 1080                 time_number = timer.timeit(number)
#    1081                 if time_number >= 0.2:
#    1082                     break
#
# ~\Anaconda3\lib\site-packages\IPython\core\magics\execution.py in timeit(self, number)
#     158         gc.disable()
#     159         try:
# --> 160             timing = self.inner(it, self.timer)
#     161         finally:
#     162             if gcold:
#
# <magic-timeit> in inner(_it, _timer)
#
# <ipython-input-28-3ced64a77d73> in find_pupple(filename)
#      21
#      22
# ---> 23     return cv2.ellipse(raw_image,ellipses[np.argmin(loss)],(255,255,255),2)
#
# UnboundLocalError: local variable 'loss' referenced before assignment
